# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
traindf=pd.read_csv("train.csv")

# %%
traindf.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
traindf.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
g = sns.FacetGrid(traindf, col="Pclass",  row="Sex")
g.map_dataframe(sns.boxplot, x="Age")

# %%
traindf.groupby(['Sex','Pclass'])['Age'].median()
# Out:
# Sex     Pclass
# female  1         35.0
#         2         28.0
#         3         21.5
# male    1         40.0
#         2         30.0
#         3         25.0
# Name: Age, dtype: float64

# %%
traindf['Age']=traindf.groupby(['Sex','Pclass'])['Age'].apply(lambda x: x.fillna(x.median()))

# %%
traindf.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
traindf['Embarked']=traindf['Embarked'].replace(np.nan,"S")

# %%
traindf.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
traindf.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
traindf.drop(['Cabin',"Ticket","Fare"],axis=1,inplace=True)

# %%
traindf.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
traindf["Title"]=traindf["Name"].str.extract('([A-Za-z]+)\.',expand=False)

# %%
traindf.drop(['Name'],axis=1,inplace=True)

# %%
traindf.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Embarked       0
# Title          0
# dtype: int64

# %%
traindf.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked Title
# 0            1         0       3    male  22.0      1      0        S    Mr
# 1            2         1       1  female  38.0      1      0        C   Mrs
# 2            3         1       3  female  26.0      0      0        S  Miss
# 3            4         1       1  female  35.0      1      0        S   Mrs
# 4            5         0       3    male  35.0      0      0        S    Mr

# %%
traindf.Embarked.unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
traindf.Title.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
traindf.Title=traindf.Title.replace(['Rev','Dr','Col','Major','Mlle','Ms','Countess','Capt','Dona','Mme','Lady','Don','Jonkheer','Sir'],"Other")

# %%
traindf.Title.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], dtype=object)

# %%
one_hot_encoded_data = pd.get_dummies(traindf, columns = ['Embarked','Title'])

# %%
one_hot_encoded_data=pd.get_dummies(one_hot_encoded_data, columns = ['Sex'])

# %%
one_hot_encoded_data
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch  Embarked_C  \
# 0              1         0       3  22.0      1      0           0
# 1              2         1       1  38.0      1      0           1
# 2              3         1       3  26.0      0      0           0
# 3              4         1       1  35.0      1      0           0
# 4              5         0       3  35.0      0      0           0
# ..           ...       ...     ...   ...    ...    ...         ...
# 886          887         0       2  27.0      0      0           0
# 887          888         1       1  19.0      0      0           0
# 888          889         0       3  21.5      1      2           0
# 889          890         1       1  26.0      0      0           1
# 890          891         0       3  32.0      0      0           0
#
#      Embarked_Q  Embarked_S  Title_Master  Title_Miss  Title_Mr  Title_Mrs  \
# 0             0           1             0           0         1          0
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
y=one_hot_encoded_data['Survived']

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X=one_hot_encoded_data.drop(['Survived','Embarked_C','Title_Master','Sex_female','PassengerId'],axis=1)

# %%
n=

# %%
n
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888  21.5
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
X['Age']=m.fit_transform(X[['Age']])

# %%
X
# Out:
#      Pclass       Age  SibSp  Parch  Embarked_Q  Embarked_S  Title_Miss  \
# 0         3  0.271174      1      0           0           1           0
# 1         1  0.472229      1      0           0           0           0
# 2         3  0.321438      0      0           0           1           1
# 3         1  0.434531      1      0           0           1           0
# 4         3  0.434531      0      0           0           1           0
# ..      ...       ...    ...    ...         ...         ...         ...
# 886       2  0.334004      0      0           0           1           0
# 887       1  0.233476      0      0           0           1           1
# 888       3  0.264891      1      2           0           1           1
# 889       1  0.321438      0      0           0           0           0
# 890       3  0.396833      0      0           1           0           0
#
#      Title_Mr  Title_Mrs  Title_Other  Sex_male
# 0           1          0            0         1
# ...

# %%
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
model.score(X,y)
# Out:
# 0.8271604938271605

# %%
submission=pd.read_csv('test.csv')

# %%
submission.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
submission.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
submission['Age']=submission.groupby(['Sex','Pclass'])['Age'].apply(lambda x: x.fillna(x.median()))

# %%
submission.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
submission.drop(['Cabin',"Ticket","Fare"],axis=1,inplace=True)

# %%
submission
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch Embarked
# 0      male  34.5      0      0        Q
# ...

# %%
submission["Title"]=submission["Name"].str.extract('([A-Za-z]+)\.',expand=False)

# %%
submission.drop(['Name'],axis=1,inplace=True)

# %%
submission.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Embarked       0
# Title          0
# dtype: int64

# %%
submission.Title=submission.Title.replace(['Rev','Dr','Col','Major','Mlle','Ms','Countess','Capt','Dona','Mme','Lady','Don','Jonkheer','Sir'],"Other")

# %%
one_hot_encoded_data1 = pd.get_dummies(submission, columns = ['Embarked','Title','Sex'])

# %%
one_hot_encoded_data1
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch  Embarked_C  Embarked_Q  \
# 0            892       3  34.5      0      0           0           1
# 1            893       3  47.0      1      0           0           0
# 2            894       2  62.0      0      0           0           1
# 3            895       3  27.0      0      0           0           0
# 4            896       3  22.0      1      1           0           0
# ..           ...     ...   ...    ...    ...         ...         ...
# 413         1305       3  24.0      0      0           0           0
# 414         1306       1  39.0      0      0           1           0
# 415         1307       3  38.5      0      0           0           0
# 416         1308       3  24.0      0      0           0           0
# 417         1309       3  24.0      1      1           1           0
#
#      Embarked_S  Title_Master  Title_Miss  Title_Mr  Title_Mrs  Title_Other  \
# ...

# %%
XX=one_hot_encoded_data1.drop(['Embarked_C','Title_Master','Sex_female'],axis=1)

# %%
XX
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch  Embarked_Q  Embarked_S  \
# 0            892       3  34.5      0      0           1           0
# 1            893       3  47.0      1      0           0           1
# 2            894       2  62.0      0      0           1           0
# 3            895       3  27.0      0      0           0           1
# 4            896       3  22.0      1      1           0           1
# ..           ...     ...   ...    ...    ...         ...         ...
# 413         1305       3  24.0      0      0           0           1
# 414         1306       1  39.0      0      0           0           0
# 415         1307       3  38.5      0      0           0           1
# 416         1308       3  24.0      0      0           0           1
# 417         1309       3  24.0      1      1           0           0
#
#      Title_Miss  Title_Mr  Title_Mrs  Title_Other  Sex_male
# 0             0         1          0            0         1
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
l=MinMaxScaler()
XX['Age']=l.fit_transform(XX[['Age']])

# %%
XX
# Out:
#      PassengerId  Pclass       Age  SibSp  Parch  Embarked_Q  Embarked_S  \
# 0            892       3  0.452723      0      0           1           0
# 1            893       3  0.617566      1      0           0           1
# 2            894       2  0.815377      0      0           1           0
# 3            895       3  0.353818      0      0           0           1
# 4            896       3  0.287881      1      1           0           1
# ..           ...     ...       ...    ...    ...         ...         ...
# 413         1305       3  0.314256      0      0           0           1
# 414         1306       1  0.512066      0      0           0           0
# 415         1307       3  0.505473      0      0           0           1
# 416         1308       3  0.314256      0      0           0           1
# 417         1309       3  0.314256      1      1           0           0
#
#      Title_Miss  Title_Mr  Title_Mrs  Title_Other  Sex_male
# ...

# %%
X2=XX.drop('PassengerId',axis=1)

# %%
X2
# Out:
#      Pclass       Age  SibSp  Parch  Embarked_Q  Embarked_S  Title_Miss  \
# 0         3  0.452723      0      0           1           0           0
# 1         3  0.617566      1      0           0           1           0
# 2         2  0.815377      0      0           1           0           0
# 3         3  0.353818      0      0           0           1           0
# 4         3  0.287881      1      1           0           1           0
# ..      ...       ...    ...    ...         ...         ...         ...
# 413       3  0.314256      0      0           0           1           0
# 414       1  0.512066      0      0           0           0           0
# 415       3  0.505473      0      0           0           1           0
# 416       3  0.314256      0      0           0           1           0
# 417       3  0.314256      1      1           0           0           0
#
#      Title_Mr  Title_Mrs  Title_Other  Sex_male
# 0           1          0            0         1
# ...

# %%
XX['Survived']=model.predict(X2)

# %%
XX
# Out:
#      PassengerId  Pclass       Age  SibSp  Parch  Embarked_Q  Embarked_S  \
# 0            892       3  0.452723      0      0           1           0
# 1            893       3  0.617566      1      0           0           1
# 2            894       2  0.815377      0      0           1           0
# 3            895       3  0.353818      0      0           0           1
# 4            896       3  0.287881      1      1           0           1
# ..           ...     ...       ...    ...    ...         ...         ...
# 413         1305       3  0.314256      0      0           0           1
# 414         1306       1  0.512066      0      0           0           0
# 415         1307       3  0.505473      0      0           0           1
# 416         1308       3  0.314256      0      0           0           1
# 417         1309       3  0.314256      1      1           0           0
#
#      Title_Miss  Title_Mr  Title_Mrs  Title_Other  Sex_male  Survived
# ...

# %%
submission=XX[['PassengerId','Survived']]

# %%
submission.to_csv('submission.csv')

# %%
df=pd.read_csv('submission.csv')

# %%
m.drop('Unnamed: 0',axis=1,inplace=True)

# %%
m.to_csv('submission.csv',index=False)

# %%
m=pd.read_csv('submission.csv')

# %%
m
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
